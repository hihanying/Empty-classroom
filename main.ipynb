# %%
url = 'https://jwxt.bupt.edu.cn/zxqDtKxJas.jsp'

# %%
from urllib import request
from bs4 import BeautifulSoup
import re

# %%
content = request.urlopen(url)
soup = BeautifulSoup(content)
print(soup)
# Out:
# <html>
# <head>
# <title>列表</title>
# <link href="/css/newcss/project.css" rel="stylesheet" type="text/css"/>
# </head>
# <body leftmargin="0" marginheight="0" marginwidth="0" style="overflow: auto;" topmargin="0">
# <form method="post" name="frm">
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td class="Linetop"></td>
# </tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0" class="title" id="tblHead" width="100%">
# <tr>
# <td width="50%">
# <table align="left" border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td>
#
# 								</td>
# <td valign="middle">
#
# 									<b>2019年12月19日<font color="red">校本部</font>无课教室列表</b>
# 								</td>
# </tr>
# </table>
# </td></tr>
# </table>
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td class="Linetop"></td>
# </tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0" class="titleTop2" width="100%">
# <tr>
# <td class="pageAlign">
# <table border="0" cellpadding="0" cellspacing="1" class="displayTag" id="user" width="100%">
# <tr>
# <td class="sortable" valign="top" width="5%">
#
# 											第1,2节
# 										</td>
# <td align="left" bgcolor="white">
# <font color="blue">教三楼:</font>3-205,
#
#
#
#
#
# 												3-217,
#
#
#
# 												3-305,
#
#
#
# 												3-333,
#
#
#
# 												3-339,
#
#
#
# 												3-405,
#
#
#
# 												3-408,
#
#
#
# 												3-411,
#
#
#
# 												3-426,
#
#
#
# 												3-433,
#
#
#
# 												3-519,
#
#
#
# 												3-537,
#
#
#
# 												3-539,
#
#
#
# 												3-546,
#
#
#
#
#
# 													<br/>
# <font color="blue">教四楼:</font>4-238,
#
#
#
#
#
# 												4-302,
#
#
#
# 												4-313,
#
#
#
# 												4-318,
#
#
#
# 												4-340,
#
#
#
# 												4-401,
#
#
#
# 												4-444,
#
# 										</td>
# </tr>
# <tr>
# <td class="sortable" valign="top" width="5%">
#
# 											第3,4节
# 										</td>
# <td align="left" bgcolor="white">
# <font color="blue">教一楼:</font>1-101,
#
#
#
#
#
#
#
# 													<br/>
# <font color="blue">教二楼:</font>2-301,
#
#
#
#
#
# 												2-441,
#
#
#
#
#
# 													<br/>
# <font color="blue">教三楼:</font>3-211,
#
#
#
#
#
# 												3-339,
#
#
#
# 												3-540,
#
#
#
#
#
# 													<br/>
# <font color="blue">教四楼:</font>4-303,
#
#
#
#
#
# 												4-313,
#
# 										</td>
# </tr>
# <tr>
# <td class="sortable" valign="top" width="5%">
#
# 											第5,6节
# 										</td>
# <td align="left" bgcolor="white">
# <font color="blue">教一楼:</font>1-101,
#
#
#
#
#
#
#
# 													<br/>
# <font color="blue">教二楼:</font>2-201,
#
#
#
#
#
# 												2-240,
#
#
#
# 												2-301,
#
#
#
# 												2-339,
#
#
#
# 												2-401,
#
#
#
# 												2-441,
#
#
#
#
#
# 													<br/>
# <font color="blue">教三楼:</font>3-205,
#
#
#
#
#
# 												3-208,
#
#
#
# 												3-211,
#
#
#
# 												3-305,
#
#
#
# 												3-308,
#
#
#
# 												3-317,
#
#
#
# 												3-326,
#
#
#
# 												3-335,
#
#
#
# 												3-337,
#
#
#
# 												3-339,
#
#
#
# 												3-405,
#
#
#
# 												3-408,
#
#
#
# 												3-411,
#
#
#
# 												3-417,
#
#
#
# 												3-426,
#
#
#
# 												3-428,
#
#
#
# 												3-433,
#
#
#
# 												3-435,
#
#
#
# 												3-437,
#
#
#
# 												3-519,
#
#
#
# 												3-535,
#
#
#
# 												3-537,
#
#
#
# 												3-539,
#
#
#
# 												3-540,
#
#
#
# 												3-546,
#
#
#
#
#
# 													<br/>
# <font color="blue">教四楼:</font>4-203,
#
#
#
#
#
# 												4-238,
#
#
#
# 												4-302,
#
#
#
# 												4-303,
#
#
#
# 												4-313,
#
#
#
# 												4-340,
#
#
#
# 												4-402,
#
# 										</td>
# </tr>
# <tr>
# <td class="sortable" valign="top" width="5%">
#
# 											第7,8节
# 										</td>
# <td align="left" bgcolor="white">
# <font color="blue">教二楼:</font>2-441,
#
#
#
#
#
#
#
# 													<br/>
# <font color="blue">教三楼:</font>3-108,
#
#
#
#
#
# 												3-308,
#
#
#
# 												3-326,
#
#
#
# 												3-333,
#
#
#
# 												3-335,
#
#
#
# 												3-337,
#
#
#
# 												3-339,
#
#
#
# 												3-408,
#
#
#
# 												3-428,
#
#
#
# 												3-519,
#
#
#
# 												3-539,
#
#
#
#
#
# 													<br/>
# <font color="blue">教四楼:</font>4-303,
#
#
#
#
#
# 												4-402,
#
# 										</td>
# </tr>
# <tr>
# <td class="sortable" valign="top" width="5%">
# 											第9节
#
# 										</td>
# <td align="left" bgcolor="white">
# <font color="blue">教二楼:</font>2-240,
#
#
#
#
#
# 												2-339,
#
#
#
# 												2-441,
#
#
#
#
#
# 													<br/>
# <font color="blue">教三楼:</font>3-205,
#
#
#
#
#
# 												3-208,
#
#
#
# 												3-305,
#
#
#
# 												3-333,
#
#
#
# 												3-339,
#
#
#
# 												3-405,
#
#
#
# 												3-433,
#
#
#
# 												3-437,
#
#
#
# 												3-539,
#
#
#
# 												3-540,
#
#
#
# 												3-546,
#
#
#
#
#
# 													<br/>
# <font color="blue">教四楼:</font>4-202,
#
#
#
#
#
# 												4-238,
#
#
#
# 												4-303,
#
#
#
# 												4-318,
#
#
#
# 												4-340,
#
#
#
# 												4-401,
#
#
#
# 												4-402,
#
#
#
# 												4-444,
#
# 										</td>
# </tr>
# <tr>
# <td class="sortable" valign="top" width="5%">
#
# 											第10,11节
# 										</td>
# <td align="left" bgcolor="white">
# <font color="blue">教一楼:</font>1-101,
#
#
#
#
#
#
#
# 													<br/>
# <font color="blue">教二楼:</font>2-240,
#
#
#
#
#
# 												2-441,
#
#
#
#
#
# 													<br/>
# <font color="blue">教三楼:</font>3-108,
#
#
#
#
#
# 												3-208,
#
#
#
# 												3-305,
#
#
#
# 												3-337,
#
#
#
# 												3-339,
#
#
#
# 												3-405,
#
#
#
# 												3-408,
#
#
#
# 												3-428,
#
#
#
# 												3-433,
#
#
#
# 												3-519,
#
#
#
# 												3-537,
#
#
#
# 												3-539,
#
#
#
# 												3-540,
#
#
#
# 												3-546,
#
#
#
#
#
# 													<br/>
# <font color="blue">教四楼:</font>4-302,
#
#
#
#
#
# 												4-303,
#
#
#
# 												4-318,
#
#
#
# 												4-401,
#
#
#
# 												4-444,
#
# 										</td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </form>
# </body>
# </html>

# %%
tags1 = soup.find_all('td',attrs={'class':'sortable','valign':'top'})
list1 = []
print(len(tags1))
for tag in tags1:
    str1 = str(tag.string)
    list1.append(re.sub('\s','',str1))
print(list1)
# Out:
# 6
# ['第1,2节', '第3,4节', '第5,6节', '第7,8节', '第9节', '第10,11节']

# %%
tags2 = soup.find_all('td',attrs={'bgcolor':'white','align':'left'})
list2 = []
for tag in tags2:
    str2 = tag.get_text()
    str2 = re.sub('\s','',str2).replace("教一楼:","").replace("教二楼:","").replace("教三楼:","").replace("教四楼:","")
    if(str2[-1]==","):
        str2 = str2[:-1]
    list2.append(str2)
for item in list2:
    print(item)
# Out:
# 3-205,3-217,3-305,3-333,3-339,3-405,3-408,3-411,3-426,3-433,3-519,3-537,3-539,3-546,4-238,4-302,4-313,4-318,4-340,4-401,4-444
# 1-101,2-301,2-441,3-211,3-339,3-540,4-303,4-313
# 1-101,2-201,2-240,2-301,2-339,2-401,2-441,3-205,3-208,3-211,3-305,3-308,3-317,3-326,3-335,3-337,3-339,3-405,3-408,3-411,3-417,3-426,3-428,3-433,3-435,3-437,3-519,3-535,3-537,3-539,3-540,3-546,4-203,4-238,4-302,4-303,4-313,4-340,4-402
# 2-441,3-108,3-308,3-326,3-333,3-335,3-337,3-339,3-408,3-428,3-519,3-539,4-303,4-402
# 2-240,2-339,2-441,3-205,3-208,3-305,3-333,3-339,3-405,3-433,3-437,3-539,3-540,3-546,4-202,4-238,4-303,4-318,4-340,4-401,4-402,4-444
# 1-101,2-240,2-441,3-108,3-208,3-305,3-337,3-339,3-405,3-408,3-428,3-433,3-519,3-537,3-539,3-540,3-546,4-302,4-303,4-318,4-401,4-444

# %%
dict1 = {}
for item in list2:
    crs=item.split(",")
    for cr in crs:
        if cr in dict1.keys():
            dict1[cr].append(list1[list2.index(item)])
        else:
            dict1[cr]=[list1[list2.index(item)]]
dict1
# Out:
# {'3-205': ['第1,2节', '第5,6节', '第9节'],
#  '3-217': ['第1,2节'],
#  '3-305': ['第1,2节', '第5,6节', '第9节', '第10,11节'],
#  '3-333': ['第1,2节', '第7,8节', '第9节'],
#  '3-339': ['第1,2节', '第3,4节', '第5,6节', '第7,8节', '第9节', '第10,11节'],
#  '3-405': ['第1,2节', '第5,6节', '第9节', '第10,11节'],
#  '3-408': ['第1,2节', '第5,6节', '第7,8节', '第10,11节'],
#  '3-411': ['第1,2节', '第5,6节'],
#  '3-426': ['第1,2节', '第5,6节'],
#  '3-433': ['第1,2节', '第5,6节', '第9节', '第10,11节'],
#  '3-519': ['第1,2节', '第5,6节', '第7,8节', '第10,11节'],
#  '3-537': ['第1,2节', '第5,6节', '第10,11节'],
#  '3-539': ['第1,2节', '第5,6节', '第7,8节', '第9节', '第10,11节'],
#  '3-546': ['第1,2节', '第5,6节', '第9节', '第10,11节'],
#  '4-238': ['第1,2节', '第5,6节', '第9节'],
#  '4-302': ['第1,2节', '第5,6节', '第10,11节'],
#  '4-313': ['第1,2节', '第3,4节', '第5,6节'],
#  '4-318': ['第1,2节', '第9节', '第10,11节'],
#  '4-340': ['第1,2节', '第5,6节', '第9节'],
#  '4-401': ['第1,2节', '第9节', '第10,11节'],
#  '4-444': ['第1,2节', '第9节', '第10,11节'],
#  '1-101': ['第3,4节', '第5,6节', '第10,11节'],
#  '2-301': ['第3,4节', '第5,6节'],
#  '2-441': ['第3,4节', '第5,6节', '第7,8节', '第9节', '第10,11节'],
#  '3-211': ['第3,4节', '第5,6节'],
#  '3-540': ['第3,4节', '第5,6节', '第9节', '第10,11节'],
#  '4-303': ['第3,4节', '第5,6节', '第7,8节', '第9节', '第10,11节'],
#  '2-201': ['第5,6节'],
#  '2-240': ['第5,6节', '第9节', '第10,11节'],
#  '2-339': ['第5,6节', '第9节'],
#  '2-401': ['第5,6节'],
#  '3-208': ['第5,6节', '第9节', '第10,11节'],
#  '3-308': ['第5,6节', '第7,8节'],
#  '3-317': ['第5,6节'],
#  '3-326': ['第5,6节', '第7,8节'],
#  '3-335': ['第5,6节', '第7,8节'],
#  '3-337': ['第5,6节', '第7,8节', '第10,11节'],
#  '3-417': ['第5,6节'],
#  '3-428': ['第5,6节', '第7,8节', '第10,11节'],
#  '3-435': ['第5,6节'],
#  '3-437': ['第5,6节', '第9节'],
#  '3-535': ['第5,6节'],
#  '4-203': ['第5,6节'],
#  '4-402': ['第5,6节', '第7,8节', '第9节'],
#  '3-108': ['第7,8节', '第10,11节'],
#  '4-202': ['第9节']}
